# %% [markdown]
# # 회귀 모델

# %% [markdown]
# ## 회귀모델의 동작 원리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# 램덤 데이터 추출
np.random.seed(0)
X = 2 * np.random.rand(100, 1)

# y = 4x + 6 의 직선 데이터에 노이즈 삽입
y = 6 + 4*X + np.random.randn(100, 1)

plt.scatter(X, y)

# %%
# a : 기울기, b = 절편, 각각 랜덤 초기화
a, b = np.random.rand(), np.random.rand()
# 학습률 
alpha = 0.05
# 몇회에 걸쳐 회귀계수를 조정할 것인지 결정
epoch = 100

for i in range(epoch):
    y_pred = a*X + b
    e = y_pred - y
    a = a - alpha*(X*e).mean() #Loss function을 미분한 수식에 따름
    b = b - alpha*(e).mean()   #Loss function을 미분한 수식에 따름
    print("a=", a.round(3), "b=", b.round(3), "error=", np.abs(e).mean().round(3))
    
xs = np.linspace(0,2,2)
ys = a*xs + b

plt.scatter(X, y)
plt.plot(xs,ys, c='r')
# Out:
# a= 0.712 b= 0.892 error= 9.354
# a= 1.164 b= 1.313 error= 8.409
# a= 1.568 b= 1.691 error= 7.561
# a= 1.929 b= 2.031 error= 6.801
# a= 2.253 b= 2.337 error= 6.119
# a= 2.542 b= 2.612 error= 5.508
# a= 2.8 b= 2.86 error= 4.959
# a= 3.03 b= 3.084 error= 4.467
# a= 3.236 b= 3.285 error= 4.026
# a= 3.42 b= 3.466 error= 3.63
# a= 3.584 b= 3.63 error= 3.274
# a= 3.73 b= 3.778 error= 2.956
# a= 3.86 b= 3.911 error= 2.67
# a= 3.976 b= 4.032 error= 2.413
# a= 4.079 b= 4.141 error= 2.183
# a= 4.171 b= 4.24 error= 1.976
# a= 4.252 b= 4.329 error= 1.791
# a= 4.324 b= 4.411 error= 1.63
# a= 4.388 b= 4.484 error= 1.495
# a= 4.445 b= 4.551 error= 1.385
# a= 4.494 b= 4.613 error= 1.301
# a= 4.538 b= 4.668 error= 1.232
# a= 4.577 b= 4.719 error= 1.18
# a= 4.61 b= 4.765 error= 1.143
# a= 4.64 b= 4.808 error= 1.112
# a= 4.666 b= 4.847 error= 1.088
# a= 4.688 b= 4.883 error= 1.067
# a= 4.707 b= 4.916 error= 1.047
# a= 4.724 b= 4.946 error= 1.031
# a= 4.738 b= 4.974 error= 1.017
# a= 4.749 b= 5.0 error= 1.006
# a= 4.759 b= 5.024 error= 0.997
# a= 4.767 b= 5.047 error= 0.989
# a= 4.774 b= 5.068 error= 0.983
# a= 4.779 b= 5.087 error= 0.978
# a= 4.783 b= 5.106 error= 0.973
# a= 4.786 b= 5.123 error= 0.969
# a= 4.788 b= 5.139 error= 0.965
# a= 4.789 b= 5.155 error= 0.962
# a= 4.789 b= 5.169 error= 0.959
# a= 4.788 b= 5.183 error= 0.957
# a= 4.787 b= 5.196 error= 0.954
# a= 4.785 b= 5.209 error= 0.952
# a= 4.783 b= 5.221 error= 0.95
# a= 4.781 b= 5.233 error= 0.947
# a= 4.778 b= 5.244 error= 0.945
# a= 4.774 b= 5.254 error= 0.943
# a= 4.771 b= 5.265 error= 0.942
# a= 4.767 b= 5.275 error= 0.94
# a= 4.763 b= 5.284 error= 0.938
# a= 4.758 b= 5.294 error= 0.937
# a= 4.754 b= 5.303 error= 0.935
# a= 4.749 b= 5.311 error= 0.934
# a= 4.744 b= 5.32 error= 0.932
# a= 4.739 b= 5.329 error= 0.931
# a= 4.734 b= 5.337 error= 0.93
# a= 4.729 b= 5.345 error= 0.928
# a= 4.724 b= 5.353 error= 0.927
# a= 4.719 b= 5.361 error= 0.926
# a= 4.713 b= 5.368 error= 0.924
# a= 4.708 b= 5.376 error= 0.923
# a= 4.703 b= 5.383 error= 0.922
# a= 4.697 b= 5.39 error= 0.921
# a= 4.692 b= 5.397 error= 0.919
# a= 4.687 b= 5.404 error= 0.918
# a= 4.681 b= 5.411 error= 0.917
# a= 4.676 b= 5.418 error= 0.916
# a= 4.671 b= 5.425 error= 0.915
# a= 4.665 b= 5.432 error= 0.914
# a= 4.66 b= 5.438 error= 0.913
# a= 4.654 b= 5.445 error= 0.913
# a= 4.649 b= 5.451 error= 0.912
# a= 4.644 b= 5.457 error= 0.911
# a= 4.639 b= 5.464 error= 0.91
# a= 4.633 b= 5.47 error= 0.909
# a= 4.628 b= 5.476 error= 0.908
# a= 4.623 b= 5.482 error= 0.907
# a= 4.618 b= 5.488 error= 0.907
# a= 4.613 b= 5.494 error= 0.906
# a= 4.608 b= 5.5 error= 0.905
# a= 4.602 b= 5.506 error= 0.904
# a= 4.597 b= 5.512 error= 0.903
# a= 4.592 b= 5.518 error= 0.903
# a= 4.587 b= 5.523 error= 0.902
# a= 4.583 b= 5.529 error= 0.901
# a= 4.578 b= 5.535 error= 0.9
# a= 4.573 b= 5.54 error= 0.9
# a= 4.568 b= 5.546 error= 0.899
# a= 4.563 b= 5.551 error= 0.898
# a= 4.558 b= 5.557 error= 0.898
# a= 4.554 b= 5.562 error= 0.897
# a= 4.549 b= 5.567 error= 0.896
# a= 4.544 b= 5.573 error= 0.896
# a= 4.54 b= 5.578 error= 0.895
# a= 4.535 b= 5.583 error= 0.894
# a= 4.531 b= 5.588 error= 0.894
# a= 4.526 b= 5.593 error= 0.893
# a= 4.522 b= 5.599 error= 0.893
# a= 4.517 b= 5.604 error= 0.892
# a= 4.513 b= 5.609 error= 0.891

# %% [markdown]
# ## 데이터 다운로드
# - 실제 키-몸무게 데이터를 사용하여 회귀 예측 모델을 만들어 본다
# - 남여 성별 정보를 사용하여 성능의 개선되는 것을 확인한다

# %%
data = pd.read_csv("https://github.com/data-labs/data/raw/main/weight-height.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
print(data.shape)
data[:5]
# Out:
# (10000, 3)
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.Gender.value_counts()
# Out:
# Male      5000
# Female    5000
# Name: Gender, dtype: int64

# %%
# 단위 변환 (인치, 파운드 --> cm, kg)
data.Height = data.Height*2.54 # cm
data.Weight = data.Weight*0.453592 # kg
data[:5]
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  109.720985
# 1   Male  174.706036   73.622732
# 2   Male  188.239668   96.497550
# 3   Male  182.196685   99.809504
# 4   Male  177.499761   93.598619

# %%
# 사본 사용 (원본 백업)
df = data.copy()
df[:3]
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  109.720985
# 1   Male  174.706036   73.622732
# 2   Male  188.239668   96.497550

# %% [markdown]
# ## 데이터 특성

# %%
x = df.Height.values
y = df.Weight.values

# %%
plt.hist(x, bins=50, width=0.5)
plt.show()

# %%
x.max()
# Out:
# 200.6568055598296

# %%
plt.hist(y, bins=50, width=0.5)
plt.show()

# %%
plt.scatter(x,y, s=0.05)

# %% [markdown]
# # 키로부터 몸무게 예측
# - 성별 정보는 사용하지 않음. 즉, 남여를 구분하지 않는다

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# 학습 및 검증 데이터 크기 확인
x_train.shape, x_test.shape, y_train.shape,y_test.shape
# Out:
# ((7500,), (2500,), (7500,), (2500,))

# %%
# 모델 생성, 학습, 사용 후 성능 보기 (R-Squared)
from sklearn.linear_model import LinearRegression
model = LinearRegression() # (1) 모델 생성
model.fit(x_train.reshape(-1,1), y_train) # (2) 학습
model.score(x_test.reshape(-1,1), y_test) # (3) 이용, 성능평가
# Out:
# 0.8545741214177273

# %%
# 학습한 계수(파라미터)
a, b = model.coef_, model.intercept_
a, b
# Out:
# (array([1.37917097]), -159.28338006622937)

# %%
# 훈련과 검증 데이터에 대한 회귀 직선 보기
plt.figure(figsize=(10,4))
xs = np.linspace(140,200,2)
ys = a*xs + b

plt.subplot(1,2,1)  
plt.title('Train Data')
plt.plot(xs,ys, c='r')
plt.scatter(x_train,y_train, s=0.05)

plt.subplot(1,2,2)  
plt.title('Test Data')
plt.plot(xs,ys, c='r')
plt.scatter(x_test,y_test, s=0.05)

# %% [markdown]
# ## 남여 구분 정보 사용
# - 추가정보를 사용함으로써 (즉, 입력 데이터의 컬럼 수를 늘임으로써) 성능이 개선되는지 확인

# %%
df[:3]
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  109.720985
# 1   Male  174.706036   73.622732
# 2   Male  188.239668   96.497550

# %%
# Gender 컬럼의 값 확인
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.head()
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  109.720985
# 1   Male  174.706036   73.622732
# 2   Male  188.239668   96.497550
# 3   Male  182.196685   99.809504
# 4   Male  177.499761   93.598619

# %%
#방법 1) sex = df.Gender.map({'Male':1, 'Female':0})
sex = df.Gender.map({'Male':1, 'Female':0})
#방법 2) sex = df.Gender.apply(lambda x: 0 if x=="Male" else 1)
df['sex'] = sex

#방법 3) 이게 정석
onehot = pd.get_dummies(df["Gender"], prefix="Gender")     #
df = pd.concat([df, onehot], axis=1)

df[:3]
# Out:
#   Gender      Height      Weight  sex  Gender_Female  Gender_Male
# 0   Male  187.571423  109.720985    1              0            1
# 1   Male  174.706036   73.622732    1              0            1
# 2   Male  188.239668   96.497550    1              0            1

# %%
sex
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %% [markdown]
# ## 키만 사용한 경우 (복습)
# - 몸무게를 예측하는데 키만 사용하고 성별 정보는 사용하지 않는 경우
# - 성능 평가는 R-Squared 값 보기

# %%
x = df.Height.values
y = df.Weight.values

x_train, x_test, y_train, y_test = train_test_split(x, y)

model = LinearRegression() # (1) 모델 생성
model.fit(x_train.reshape(-1,1), y_train)
model.score(x_test.reshape(-1,1), y_test)
# Out:
# 0.8549817645742224

# %% [markdown]
# ## 파라미터 최적화
# - LinearRegressor에는 하이퍼파라미터의 선택지가 적다. 대체로 알아서 한다.
# - 세부적으로 조절해보고 싶을 때는 SGDRegressor를 사용한다.
#  - https://woojin.tistory.com/9 => LinearRegressor와 SGDRegressor의 차이를 설명하고 있다.

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = scaler.fit_transform(df.Height.values.reshape(-1,1))
y = scaler.fit_transform(df.Weight.values.reshape(-1,1))

x_train, x_test, y_train, y_test = train_test_split(x, y)

models = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)

models.fit(x_train, y_train)
print(models.score(x_test, y_test))

print(models.coef_, models.intercept_)
# Out:
# 0.8560105589012655
# [0.92462751] [0.01283749]
# c:\Users\krkim1\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
a = models.coef_
b = models.intercept_

# 훈련과 검증 데이터에 대한 회귀 직선 보기
plt.figure(figsize=(10,4))
xs = [-3,3]
ys = a*xs + b

plt.subplot(1,2,1)  
plt.title('Train Data')
plt.plot(xs,ys, c='r')
plt.scatter(x_train,y_train, s=0.05)

plt.subplot(1,2,2)  
plt.title('Test Data')
plt.plot(xs,ys, c='r')
plt.scatter(x_test,y_test, s=0.05)

# %% [markdown]
# # 성별과 키, 두개의 컬럼을 사용
# - 남여의 키-몸무게 관계가 다르므로 추가 정보 사용으로 성능이 개선될 것으로 예상
# - 2차원 배열 구조를 가지므로 소문자 x 대시 대문자 X를 사용한다
#  - 2차원 배열을 사용하므로 reshape(-1,1)이 필요 없다

# %%
X = df[["Height", "Gender_Female", "Gender_Male"]]
y = df.Weight.values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=9)
model = LinearRegression() 
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9018876478426087

# %%
X[:3]
# Out:
#        Height  Gender_Female  Gender_Male
# 0  187.571423              0            1
# 1  174.706036              0            1
# 2  188.239668              0            1

# %% [markdown]
# - 성별 정보를 추가로 사용하여 성능이 개선되었다

# %% [markdown]
# ## 다중 회귀 모델
# - 입력 변수가 2개인 다중회귀 모델이므로 파라미터가 변수의 수만큼 자동으로 2개 만들어진다
# - $\hat{y} = b +a_{1}x_{1} + a_{2}x_{2}$
# - $x_{1}$: 성별, $x_{2}$: 키

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 1.0683633 -4.3634365  4.3634365]
# -106.84102939786163

# %%
a1, a2, a3 = model.coef_[0], model.coef_[1], model.coef_[2]
b1 = model.intercept_

# %% [markdown]
# ## 회귀직선
# - (1)남성의 경우 회귀 직선 (Gender=0, 갈색 점): 파란색 선
# - (2)여성의 경우 회귀 직선 (Gender=1, 노란색 점): 붉은색 선
# - (3)성별을 구분하지 않는 전체 대상의 회귀직선: 검정색

# %%
xs = np.linspace(140,200,2)
plt.figure(figsize=(8,6))
plt.scatter(X_train.Height, y_train, c=X_train.Gender_Male, s=0.1)

# 남성의 경우 회귀 직선 (Gender=0)
ys = a1*xs + a2*0 + a3*1 + b1
plt.plot(xs, ys, c='b')

# 여성의 경우 회귀 직선 (Gender=1)
ys = a1*xs + a2*1 + a3*0 + b1
plt.plot(xs, ys, c='r')

# 남여 구분 없는 경우 회귀 직선 (a, b 파라미터 사용)
ys = a*xs + b
plt.plot(xs, ys, c='k')

# %% [markdown]
# - 다른 카테고리 변수 추가

# %%
df[:3]
# Out:
#   Gender      Height      Weight  sex  Gender_Female  Gender_Male
# 0   Male  187.571423  109.720985    1              0            1
# 1   Male  174.706036   73.622732    1              0            1
# 2   Male  188.239668   96.497550    1              0            1

# %%
df["Nation"] = np.random.choice(["China","Korea","Japan"], 10000)
df[:10]
# Out:
#   Gender      Height      Weight  sex  Gender_Female  Gender_Male Nation
# 0   Male  187.571423  109.720985    1              0            1  Korea
# 1   Male  174.706036   73.622732    1              0            1  Japan
# 2   Male  188.239668   96.497550    1              0            1  Japan
# 3   Male  182.196685   99.809504    1              0            1  Japan
# 4   Male  177.499761   93.598619    1              0            1  China
# 5   Male  170.822660   69.042216    1              0            1  China
# 6   Male  174.714106   83.428219    1              0            1  China
# 7   Male  173.605229   76.190352    1              0            1  Japan
# 8   Male  170.228132   79.800187    1              0            1  Japan
# 9   Male  161.179495   70.941642    1              0            1  Japan

# %%
df.Nation.value_counts()
# Out:
# Korea    3405
# China    3328
# Japan    3267
# Name: Nation, dtype: int64

# %%
#df_nat = pd.get_dummies(df["Nation"])
df_nat = pd.get_dummies(df)
df_nat[:3]
# Out:
#        Height      Weight  sex  Gender_Female  Gender_Male  Gender_Female  \
# 0  187.571423  109.720985    1              0            1              0
# 1  174.706036   73.622732    1              0            1              0
# 2  188.239668   96.497550    1              0            1              0
#
#    Gender_Male  Nation_China  Nation_Japan  Nation_Korea
# 0            1             0             0             1
# 1            1             0             1             0
# 2            1             0             1             0

# %%
df = df.join(df_n)
df[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df = df.join(df_n)
#       2 df[:3]
#
# NameError: name 'df_n' is not defined

# %%
data[:3]
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  109.720985
# 1   Male  174.706036   73.622732
# 2   Male  188.239668   96.497550

# %%
pd.get_dummies(data.Gender)
# Out:
#       Female  Male
# 0          0     1
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 9995       1     0
# 9996       1     0
# 9997       1     0
# 9998       1     0
# 9999       1     0
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## 기타 성능 평가
# - MAE, RMSE 값은 각각 mean_absolute_error, mean_squared_error 함수가 제공한다

# %%
y_pred = model.predict(X_test)

# %%
# MAE
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(y_test, y_pred)
# Out:
# 3.633129097352219

# %%
# RMSE 를 얻으려면 squared=False 를 설정한다
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 4.578409817362492

# %%
error = np.abs(y_pred-y_test)
error.max()
# Out:
# 17.438196005504523

# %%
plt.scatter(y_pred, error, s=0.5)
